# %% [markdown]
# ## 1 Problem Statement
#
# Given a nested dictionary where:
# - Keys are strings
# - Values can be integers or dictionaries
#
# Find all occurrences of a specific key (e.g. `'a'`) at any depth and
# return the **sum of its values**.
#
# ### Example
# ```python
# data = {
#     "a": 1,
#     "b": {
#         "a": 2,
#         "c": {
#             "a": 3
#         }
#     }
# }

# %%
nested_dict = {
    "a": 1,
    "b": {
        "a": 2,
        "c": {
            "a": 3,
            "d": 4
        }
    },
    "a_extra": 10
}

result = sum_key_values(nested_dict, "a")
result

# %% [markdown]
# def sum_key_values():
#     pass

# %% [markdown]
# ## 2 Problem Statement
#
# Given an integer `n`, determine whether it is a **prime number**.
#
# A prime number is a number greater than 1 that has **exactly two divisors**:
# 1 and itself.
#
# ### Example
#
# Input:
# ```python
# n = 7
